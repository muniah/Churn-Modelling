# %%
# Part 1 - Data Preprocessing

# Importing the libraries
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Importing the dataset
dataset = pd.read_csv('Churn_Modelling.csv')

# %%
dataset.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
X = dataset.iloc[:, 3:13].values
y = dataset.iloc[:, 13].values

# %%
# Encoding categorical data
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
labelencoder_X_1 = LabelEncoder()
X[:, 1] = labelencoder_X_1.fit_transform(X[:, 1])
labelencoder_X_2 = LabelEncoder()
X[:, 2] = labelencoder_X_2.fit_transform(X[:, 2])
onehotencoder = OneHotEncoder(categories = 'auto')
X = onehotencoder.fit_transform(X).toarray()
X = X[:, 1:]

# %%
# Splitting the dataset into the Training set and Test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
# Part 2 - Now let's make the ANN!

# Importing the Keras libraries and packages
import keras
from keras.models import Sequential
from keras.layers import Dense

# Initialising the ANN
classifier = Sequential()

# Adding the input layer and the first hidden layer
Dense(activation="relu", input_dim=11, units=6, kernel_initializer="uniform")

# Adding the second hidden layer
classifier.add(Dense(units = 6, kernel_initializer = 'uniform', activation = 'relu'))

# Adding the output layer
classifier.add(Dense(units= 1, kernel_initializer = 'uniform', activation = 'sigmoid'))

# Compiling the ANN
classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# Fitting the ANN to the Training set
classifier.fit(X_train, y_train, batch_size = 10, epochs = 100)
# Out:
# Using TensorFlow backend.
# Epoch 1/100
# 8000/8000 [==============================] - 3s 334us/step - loss: 0.5367 - accuracy: 0.7943
# Epoch 2/100
# 8000/8000 [==============================] - 2s 299us/step - loss: 0.4565 - accuracy: 0.7960
# Epoch 3/100
# 8000/8000 [==============================] - 2s 306us/step - loss: 0.3824 - accuracy: 0.7960
# Epoch 4/100
# 8000/8000 [==============================] - 2s 312us/step - loss: 0.3049 - accuracy: 0.7960
# Epoch 5/100
# 8000/8000 [==============================] - 2s 309us/step - loss: 0.2539 - accuracy: 0.8060
# Epoch 6/100
# 8000/8000 [==============================] - 2s 307us/step - loss: 0.2311 - accuracy: 0.8710
# Epoch 7/100
# 8000/8000 [==============================] - 2s 310us/step - loss: 0.2192 - accuracy: 0.8781
# Epoch 8/100
# 8000/8000 [==============================] - 3s 326us/step - loss: 0.2158 - accuracy: 0.8795
# Epoch 9/100
# 8000/8000 [==============================] - 3s 341us/step - loss: 0.2142 - accuracy: 0.8801
# Epoch 10/100
# 8000/8000 [==============================] - 2s 308us/step - loss: 0.2131 - accuracy: 0.8809
# Epoch 11/100
# 8000/8000 [==============================] - 2s 309us/step - loss: 0.2122 - accuracy: 0.8816
# Epoch 12/100
# 8000/8000 [==============================] - 3s 321us/step - loss: 0.2115 - accuracy: 0.8821
# Epoch 13/100
# 8000/8000 [==============================] - 3s 352us/step - loss: 0.2102 - accuracy: 0.8839
# Epoch 14/100
# 8000/8000 [==============================] - 3s 343us/step - loss: 0.2054 - accuracy: 0.8882
# Epoch 15/100
# 8000/8000 [==============================] - 3s 328us/step - loss: 0.2008 - accuracy: 0.8926
# Epoch 16/100
# 8000/8000 [==============================] - 2s 309us/step - loss: 0.1996 - accuracy: 0.8938
# Epoch 17/100
# 8000/8000 [==============================] - 2s 308us/step - loss: 0.1988 - accuracy: 0.8942
# Epoch 18/100
# 8000/8000 [==============================] - 2s 311us/step - loss: 0.1963 - accuracy: 0.8966
# Epoch 19/100
# 8000/8000 [==============================] - 3s 314us/step - loss: 0.1949 - accuracy: 0.8980
# Epoch 20/100
# 8000/8000 [==============================] - 3s 319us/step - loss: 0.1944 - accuracy: 0.8984
# Epoch 21/100
# 8000/8000 [==============================] - 3s 314us/step - loss: 0.1939 - accuracy: 0.8989
# Epoch 22/100
# 8000/8000 [==============================] - 3s 330us/step - loss: 0.1933 - accuracy: 0.8992
# Epoch 23/100
# 8000/8000 [==============================] - 3s 327us/step - loss: 0.1928 - accuracy: 0.8997
# Epoch 24/100
# 8000/8000 [==============================] - 3s 327us/step - loss: 0.1922 - accuracy: 0.9004
# Epoch 25/100
# 8000/8000 [==============================] - 3s 322us/step - loss: 0.1918 - accuracy: 0.9007
# Epoch 26/100
# 8000/8000 [==============================] - 3s 323us/step - loss: 0.1917 - accuracy: 0.9007
# Epoch 27/100
# 8000/8000 [==============================] - 3s 362us/step - loss: 0.1911 - accuracy: 0.9011
# Epoch 28/100
# 8000/8000 [==============================] - 3s 407us/step - loss: 0.1886 - accuracy: 0.9034
# Epoch 29/100
# 8000/8000 [==============================] - 3s 319us/step - loss: 0.1884 - accuracy: 0.9038
# Epoch 30/100
# 8000/8000 [==============================] - 3s 315us/step - loss: 0.1884 - accuracy: 0.9038
# Epoch 31/100
# 8000/8000 [==============================] - 3s 318us/step - loss: 0.1884 - accuracy: 0.9038
# Epoch 32/100
# 8000/8000 [==============================] - 3s 322us/step - loss: 0.1881 - accuracy: 0.9040
# Epoch 33/100
# 8000/8000 [==============================] - 3s 322us/step - loss: 0.1878 - accuracy: 0.9043
# Epoch 34/100
# 8000/8000 [==============================] - 3s 337us/step - loss: 0.1878 - accuracy: 0.9043
# Epoch 35/100
# 8000/8000 [==============================] - 3s 325us/step - loss: 0.1878 - accuracy: 0.9043
# Epoch 36/100
# 8000/8000 [==============================] - 3s 325us/step - loss: 0.1878 - accuracy: 0.9043
# Epoch 37/100
# 8000/8000 [==============================] - 3s 324us/step - loss: 0.1876 - accuracy: 0.9043
# Epoch 38/100
# 8000/8000 [==============================] - 3s 330us/step - loss: 0.1871 - accuracy: 0.9049
# Epoch 39/100
# 8000/8000 [==============================] - 3s 377us/step - loss: 0.1860 - accuracy: 0.9059
# Epoch 40/100
# 8000/8000 [==============================] - 3s 327us/step - loss: 0.1858 - accuracy: 0.9060
# Epoch 41/100
# 8000/8000 [==============================] - 2s 310us/step - loss: 0.1857 - accuracy: 0.9061
# Epoch 42/100
# 8000/8000 [==============================] - 2s 312us/step - loss: 0.1853 - accuracy: 0.9062
# Epoch 43/100
# 8000/8000 [==============================] - 3s 317us/step - loss: 0.1844 - accuracy: 0.9072
# Epoch 44/100
# 8000/8000 [==============================] - 3s 315us/step - loss: 0.1842 - accuracy: 0.9074
# Epoch 45/100
# 8000/8000 [==============================] - 3s 313us/step - loss: 0.1842 - accuracy: 0.9074
# Epoch 46/100
# 8000/8000 [==============================] - 3s 326us/step - loss: 0.1842 - accuracy: 0.9074
# Epoch 47/100
# 8000/8000 [==============================] - 3s 335us/step - loss: 0.1842 - accuracy: 0.9074
# Epoch 48/100
# 8000/8000 [==============================] - 3s 377us/step - loss: 0.1842 - accuracy: 0.9074
# Epoch 49/100
# 8000/8000 [==============================] - 4s 461us/step - loss: 0.1842 - accuracy: 0.9074
# Epoch 50/100
# 8000/8000 [==============================] - 3s 377us/step - loss: 0.1842 - accuracy: 0.90740s - loss: 0
# Epoch 51/100
# 8000/8000 [==============================] - 3s 332us/step - loss: 0.1842 - accuracy: 0.9074
# Epoch 52/100
# 8000/8000 [==============================] - 2s 278us/step - loss: 0.1842 - accuracy: 0.9074
# Epoch 53/100
# 8000/8000 [==============================] - 2s 283us/step - loss: 0.1842 - accuracy: 0.9074
# Epoch 54/100
# 8000/8000 [==============================] - 2s 297us/step - loss: 0.1841 - accuracy: 0.9074
# Epoch 55/100
# 8000/8000 [==============================] - 2s 312us/step - loss: 0.1830 - accuracy: 0.9084
# Epoch 56/100
# 8000/8000 [==============================] - 4s 496us/step - loss: 0.1830 - accuracy: 0.9084
# Epoch 57/100
# 8000/8000 [==============================] - 3s 369us/step - loss: 0.1830 - accuracy: 0.9084
# Epoch 58/100
# 8000/8000 [==============================] - 3s 317us/step - loss: 0.1830 - accuracy: 0.9084
# Epoch 59/100
# 8000/8000 [==============================] - 2s 308us/step - loss: 0.1831 - accuracy: 0.9084
# Epoch 60/100
# 8000/8000 [==============================] - 3s 416us/step - loss: 0.2398 - accuracy: 0.8855
# Epoch 61/100
# 8000/8000 [==============================] - 3s 421us/step - loss: 0.4221 - accuracy: 0.8699
# Epoch 62/100
# 8000/8000 [==============================] - 4s 455us/step - loss: 0.1437 - accuracy: 0.9509
# Epoch 63/100
# 8000/8000 [==============================] - 3s 406us/step - loss: 0.0850 - accuracy: 0.9815
# Epoch 64/100
# 8000/8000 [==============================] - 3s 358us/step - loss: 0.0513 - accuracy: 0.9923
# Epoch 65/100
# 8000/8000 [==============================] - 5s 634us/step - loss: 0.0343 - accuracy: 0.9950
# Epoch 66/100
# 8000/8000 [==============================] - 3s 407us/step - loss: 0.0235 - accuracy: 0.9971
# Epoch 67/100
# 8000/8000 [==============================] - 3s 336us/step - loss: 0.0169 - accuracy: 0.9985
# Epoch 68/100
# 8000/8000 [==============================] - 2s 301us/step - loss: 0.0129 - accuracy: 0.9989
# Epoch 69/100
# 8000/8000 [==============================] - 3s 326us/step - loss: 0.0106 - accuracy: 0.9989
# Epoch 70/100
# 8000/8000 [==============================] - 2s 308us/step - loss: 0.0091 - accuracy: 0.9990
# Epoch 71/100
# 8000/8000 [==============================] - 4s 516us/step - loss: 0.0083 - accuracy: 0.9990
# Epoch 72/100
# 8000/8000 [==============================] - 3s 375us/step - loss: 0.0077 - accuracy: 0.9990
# Epoch 73/100
# 8000/8000 [==============================] - 2s 286us/step - loss: 0.0073 - accuracy: 0.9990
# Epoch 74/100
# 8000/8000 [==============================] - 3s 403us/step - loss: 0.0070 - accuracy: 0.99900s - loss: 0.0072 - accura
# Epoch 75/100
# 8000/8000 [==============================] - 5s 594us/step - loss: 0.0068 - accuracy: 0.9990
# Epoch 76/100
# 8000/8000 [==============================] - 6s 730us/step - loss: 0.0385 - accuracy: 0.9920
# Epoch 77/100
# 8000/8000 [==============================] - 3s 427us/step - loss: 0.1353 - accuracy: 0.9693
# Epoch 78/100
# 8000/8000 [==============================] - 3s 367us/step - loss: 0.0094 - accuracy: 0.9984
# Epoch 79/100
# 8000/8000 [==============================] - 6s 776us/step - loss: 0.0085 - accuracy: 0.9985
# Epoch 80/100
# 8000/8000 [==============================] - 9s 1ms/step - loss: 0.0083 - accuracy: 0.9985
# Epoch 81/100
# 8000/8000 [==============================] - 3s 363us/step - loss: 0.0073 - accuracy: 0.9985
# Epoch 82/100
# 8000/8000 [==============================] - 2s 304us/step - loss: 0.0067 - accuracy: 0.9986
# Epoch 83/100
# 8000/8000 [==============================] - 3s 315us/step - loss: 0.0062 - accuracy: 0.9985
# Epoch 84/100
# 8000/8000 [==============================] - 3s 325us/step - loss: 0.0053 - accuracy: 0.9986
# Epoch 85/100
# 8000/8000 [==============================] - 3s 332us/step - loss: 0.0046 - accuracy: 0.9994
# Epoch 86/100
# 8000/8000 [==============================] - 3s 325us/step - loss: 0.0041 - accuracy: 0.9995
# Epoch 87/100
# 8000/8000 [==============================] - 2s 311us/step - loss: 0.0038 - accuracy: 0.9995
# Epoch 88/100
# 8000/8000 [==============================] - 3s 331us/step - loss: 0.0037 - accuracy: 0.9995
# Epoch 89/100
# 8000/8000 [==============================] - 3s 350us/step - loss: 0.0036 - accuracy: 0.9995
# Epoch 90/100
# 8000/8000 [==============================] - 3s 332us/step - loss: 0.0036 - accuracy: 0.9995
# Epoch 91/100
# 8000/8000 [==============================] - 3s 417us/step - loss: 0.0047 - accuracy: 0.9990
# Epoch 92/100
# 8000/8000 [==============================] - 3s 437us/step - loss: 0.0061 - accuracy: 0.9989
# Epoch 93/100
# 8000/8000 [==============================] - 3s 353us/step - loss: 0.0093 - accuracy: 0.9981
# Epoch 94/100
# 8000/8000 [==============================] - 3s 391us/step - loss: 0.0060 - accuracy: 0.9991
# Epoch 95/100
# 8000/8000 [==============================] - 3s 330us/step - loss: 0.0058 - accuracy: 0.9991
# Epoch 96/100
# 8000/8000 [==============================] - 3s 388us/step - loss: 0.0057 - accuracy: 0.9991
# Epoch 97/100
# 8000/8000 [==============================] - 3s 371us/step - loss: 0.0057 - accuracy: 0.9991
# Epoch 98/100
# 8000/8000 [==============================] - 4s 450us/step - loss: 0.0057 - accuracy: 0.9991
# Epoch 99/100
# 8000/8000 [==============================] - 3s 350us/step - loss: 0.0057 - accuracy: 0.9991
# Epoch 100/100
# 8000/8000 [==============================] - 3s 346us/step - loss: 0.0057 - accuracy: 0.9991

# %%
# Part 3 - Making the predictions and evaluating the model

# Predicting the Test set results
y_pred = classifier.predict(X_test)
y_pred = (y_pred > 0.5)

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# %%
cm
# Out:
# array([[1595,    0],
#        [ 405,    0]])

# %%
submission = pd.DataFrame( data= y_pred )
submission.to_csv('Churn_rate.csv')
